# %%
import pandas as pd
pd.set_option('display.max_row',500)
pd.set_option('display.max_columns',100)
pd.set_option('display.unicode.east_asian_width',True) 
import numpy as np
import matplotlib.pyplot as plt

from wordcloud import WordCloud,STOPWORDS
from PIL import Image 
import collections

# %%
fontpath = './malgun.ttf'

# %%
content_words = pd.read_csv('./crawling/cleaned_daum_book.csv',index_col=0)
print(content_words.info())
print(content_words.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12639 entries, 0 to 12638
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            12639 non-null  object
#  1   content          12639 non-null  object
#  2   cleaned_content  12639 non-null  object
# dtypes: object(3)
# memory usage: 395.0+ KB
# None
#                                  title  \
# 0                 유시민의 경제학 카페
# 1  좋은 기업을 넘어... 위대한 기업으로
# 2                             포지셔닝
# 3                          전쟁의 기술
# 4                           부자사전 1
#
#                                                                            content  \
# 0  오늘의 책\n(2011.03.15 선정)\n평범한 사람들을 위한 경제학 도서\n넘치...
# 1  오늘의 책\n(2007.02.08 선정)\n또 하나의 기업경영 바이블\n무엇이 위대...
# 2  오늘의 책\n(2007.09.03 선정)\n마케팅과 광고 담당자들의 오랜 ‘경전’\...
# 3  책소개\n위대한 승리자들의 비밀 전략술을 철저히 분석한 21세기판 손자병법!\n\n...
# 4  오늘의 책\n(2006.04.24 선정)\n대한민국 알부자 100인의 돈 버는 노하...
#
# ...

# %%
book_title='백범일지'

# %%
book_idx = content_words[content_words['title']==book_title].index[0]

# %%
tokened_content_words = content_words['cleaned_content'][book_idx].split(' ')

# %%
textdict = collections.Counter(tokened_content_words)

# %%
wordcloude_img = WordCloud(background_color = 'white', max_words=2000, font_path=fontpath).generate_from_frequencies(textdict)
plt.figure(figsize=(8,8))
plt.imshow(wordcloude_img, interpolation='bilinear')
plt.axis('off')
plt.show()
